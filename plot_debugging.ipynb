# %%
from gwpy.timeseries import TimeSeries
import matplotlib.pyplot as plt
import numpy as np

# %%
lock_segments = [[1377586818.0, 1377586818.0 + 30*60]]

for start_stop in lock_segments:
    gps_start_time = start_stop[0]
    gps_end_time = start_stop[1]

    data = TimeSeries.fetch('H1:GDS-CALIB_KAPPA_C',
                             gps_start_time,
                             gps_end_time,
                             allow_tape=True)
# Out:
# read_server_response: Wrong length read (0)Error in daq_send: unknown error
# read_server_response: Wrong length read (0)/cvmfs/software.igwn.org/conda/envs/igwn/lib/python3.10/site-packages/gwpy/timeseries/core.py:1144: NDSWarning: failed to fetch data for H1:GDS-CALIB_KAPPA_C in interval [1377586818.0, 1377588618.0): Low level daq error occured [-1]: unknown error
#   warnings.warn(

# %%
plot = data.plot()
ax = plot.gca()

# %%
plot
# Out:
# <Plot size 1200x400 with 1 Axes>

# %%
len(np.where(data.value >= 0)[0])
# Out:
# 162

# %%
time
# Out:
# 1377600944.3125

# %%
ax.axvline(time, 0, ax.get_ylim()[1])
ax.set_xlim([1377582807.0 - 1020, ax.get_xlim()[1]])
# Out:
# (1377581787.0, 1377601217.9375)

# %%
ax.get_ylim()
# Out:
# (-35.5862391680479, 2.5414836496114734)

# %%
plt.show(ax)
# Out:
# <Plot size 1200x400 with 1 Axes>

# %%
np.where(data.value == 4.03e5)
# Out:
# (array([], dtype=int64),)

# %%
# Out:
# 55415
